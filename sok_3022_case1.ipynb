# %% [markdown]
# <a href="https://colab.research.google.com/github/PederRonning/SOK3022/blob/main/sok_3022_case1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Starter med å importere to viktig libraries for LSTM

import tensorflow as tf
import pandas as pd

# Leser csv filen
df = pd.read_csv('/content/derivative.csv', delimiter=';')
#df = df.drop(0) # fjern første rad som hadde kolonnenavnene
df.head()
# Out:
#          date  Price  Adjusted Price  ExercisePrice  Settlement  \
# 0  2020-07-02  2.731        2.326168            5.0        0.25
# 1  2020-07-03  2.710        2.308281            5.0        0.27
# 2  2020-07-07  2.808        2.391754            5.0        0.27
# 3  2020-07-08  2.743        2.336389            5.0        0.27
# 4  2020-07-09  2.697        2.297208            5.0        0.23
#
#    EndofDayDelta  Volatility  VolatilityForValuation
# 0        29.9618      38.717                  38.717
# 1        30.6566      38.032                  38.032
# 2        30.5772      37.147                  37.147
# 3        30.4483      37.230                  37.230
# 4        28.4804      36.824                  36.824

# %%
df.shape
# Out:
# (579, 8)

# %%
df.tail()
# Out:
#            date  Price  Adjusted Price  ExercisePrice  Settlement  \
# 574  2023-09-22  4.710           4.710            5.0        0.46
# 575  2023-09-26  4.678           4.678            5.0        0.42
# 576  2023-09-27  4.477           4.477            5.0        0.42
# 577  2023-09-28  4.521           4.521            5.0        0.33
# 578  2023-09-29  4.582           4.582            5.0        0.34
#
#      EndofDayDelta  Volatility  VolatilityForValuation
# 574        51.2059        27.0                  27.210
# 575        48.7327        27.0                  27.675
# 576        48.5023        27.0                  27.629
# 577        42.0959        27.0                  27.611
# 578        43.3272        27.0                  27.412
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Price'].plot(kind='hist', bins=20, title='Price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Adjusted Price'].plot(kind='hist', bins=20, title='Adjusted Price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Settlement'].plot(kind='hist', bins=20, title='Settlement')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['EndofDayDelta'].plot(kind='hist', bins=20, title='EndofDayDelta')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('date').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='Price', y='Adjusted Price', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='Adjusted Price', y='Settlement', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='Settlement', y='EndofDayDelta', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='EndofDayDelta', y='VolatilityForValuation', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['Price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('date')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='date', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('Price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['Adjusted Price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('date')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='date', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('Adjusted Price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['Settlement']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('date')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='date', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('Settlement')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['EndofDayDelta']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('date')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='date', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('EndofDayDelta')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_13['Price'].plot(kind='line', figsize=(8, 4), title='Price')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['Adjusted Price'].plot(kind='line', figsize=(8, 4), title='Adjusted Price')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['Settlement'].plot(kind='line', figsize=(8, 4), title='Settlement')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['EndofDayDelta'].plot(kind='line', figsize=(8, 4), title='EndofDayDelta')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_17['date'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_17, x='Price', y='date', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_18['date'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_18, x='Adjusted Price', y='date', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_19['date'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_19, x='Settlement', y='date', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_20['date'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_20, x='EndofDayDelta', y='date', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
import matplotlib.pyplot as plt
import datetime

df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
df['Price'] = df['Price'].astype(float)

# %%
df = df.sort_values(by='date')

# %%
# Plot the data
plt.figure(figsize=(10, 5))
plt.plot(df['date'], df['Price'], label='Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Price over Time')
plt.legend()
plt.show()

# %%
### Funksjon som endrer et 'Object' med splitten '-' til datetime-variabel.
def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2]) # Splitter på hver int (heltall)
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('2023-03-19')
type(datetime_object)
# Out:
# datetime.datetime

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
    # Konverter strengdatoer til datetime
    first_date = pd.to_datetime(first_date_str)
    last_date = pd.to_datetime(last_date_str)

    # Sett 'Date' som indeks og sorter
    dataframe = dataframe.set_index('date').sort_index()

    target_date = first_date
    dates, X, Y = [], [], []

    last_time = False

    while not last_time:
        # Hent n+1 siste rader opp til target_date
        df_subset = dataframe.loc[:target_date].tail(n + 1)

        # Sjekk om det er nok data
        if len(df_subset) != n + 1:
            print(f"Feil: Vindu av størrelse {n} er for stort for {target_date}")
            return None

        # Hent verdiene (bruk 'Price' istedenfor 'Close')
        values = df_subset['Price'].to_numpy()
        x, y = values[:-1], values[-1]

        dates.append(target_date)
        X.append(x)
        Y.append(y)

        # Finn neste gyldige dato i indeksen
        try:
            current_idx = dataframe.index.get_loc(target_date)
            next_date = dataframe.index[current_idx + 1]
        except IndexError:
            break  # Ingen flere datoer

        target_date = next_date

        # Avslutt hvis vi når siste dato
        if target_date > last_date:
            last_time = True

    # Bygg resultatdataframe
    ret_df = pd.DataFrame({'Target Date': dates})
    X = np.array(X)

    for i in range(n):
        ret_df[f'Target-{n-i}'] = X[:, i]

    ret_df['Target'] = Y

    return ret_df

# Eksempel på bruk
windowed_df = df_to_windowed_df(
    df,
    first_date_str='2020-07-08',
    last_date_str='2023-08-10',
    n=3
)
windowed_df
# Out:
#     Target Date  Target-3  Target-2  Target-1  Target
# 0    2020-07-08     2.731     2.710     2.808   2.743
# 1    2020-07-09     2.710     2.808     2.743   2.697
# 2    2020-07-10     2.808     2.743     2.697   2.754
# 3    2020-07-14     2.743     2.697     2.754   2.835
# 4    2020-07-16     2.697     2.754     2.835   2.830
# ..          ...       ...       ...       ...     ...
# 542  2023-08-03     4.939     4.908     4.833   4.892
# 543  2023-08-04     4.908     4.833     4.892   4.953
# 544  2023-08-08     4.833     4.892     4.953   4.958
# 545  2023-08-09     4.892     4.953     4.958   4.996
# 546  2023-08-10     4.953     4.958     4.996   5.030
#
# [547 rows x 5 columns]

# %%
# Her konverteres winowed_df om til våre features (X) og target (y). Kilde: Gregg Hogg (YouTube)

def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((547,), (547, 3, 1), (547,))

# %%
q_80 = int(len(dates) * .80)
q_90 = int(len(dates) * .90)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]
plt.figure(figsize=(10, 5))
plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

# Formaterer x-aksen til å vise datoer og roterer dem
plt.gcf().autofmt_xdate()  # Automatisk rotasjon av datoer fordi det ser pent ut:)

# Adder labels og title
plt.xlabel('Date')
plt.ylabel('Euro')
plt.title('Opsjoner')

plt.legend(['Train', 'Validation', 'Test'])

# Vis plot
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

# EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=500, callbacks=[early_stopping])

#model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=500)
# Out:
# Epoch 1/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - loss: 15.2400 - mean_absolute_error: 3.8544 - val_loss: 12.4061 - val_mean_absolute_error: 3.4958
# Epoch 2/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.8933 - mean_absolute_error: 2.7287 - val_loss: 0.9911 - val_mean_absolute_error: 0.9463
# Epoch 3/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4714 - mean_absolute_error: 0.5941 - val_loss: 0.2010 - val_mean_absolute_error: 0.3646
# Epoch 4/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1829 - mean_absolute_error: 0.3579 - val_loss: 0.3032 - val_mean_absolute_error: 0.4806
# Epoch 5/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1077 - mean_absolute_error: 0.2605 - val_loss: 0.0789 - val_mean_absolute_error: 0.2396
# Epoch 6/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0886 - mean_absolute_error: 0.2428 - val_loss: 0.1261 - val_mean_absolute_error: 0.2863
# Epoch 7/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0726 - mean_absolute_error: 0.2146 - val_loss: 0.0771 - val_mean_absolute_error: 0.2438
# Epoch 8/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0601 - mean_absolute_error: 0.2015 - val_loss: 0.0870 - val_mean_absolute_error: 0.2464
# Epoch 9/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0561 - mean_absolute_error: 0.1948 - val_loss: 0.0723 - val_mean_absolute_error: 0.2302
# Epoch 10/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0517 - mean_absolute_error: 0.1868 - val_loss: 0.0742 - val_mean_absolute_error: 0.2260
# Epoch 11/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0478 - mean_absolute_error: 0.1768 - val_loss: 0.0682 - val_mean_absolute_error: 0.2159
# Epoch 12/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0441 - mean_absolute_error: 0.1734 - val_loss: 0.0602 - val_mean_absolute_error: 0.2038
# Epoch 13/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0426 - mean_absolute_error: 0.1691 - val_loss: 0.0579 - val_mean_absolute_error: 0.1960
# Epoch 14/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0381 - mean_absolute_error: 0.1607 - val_loss: 0.0603 - val_mean_absolute_error: 0.1943
# Epoch 15/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0348 - mean_absolute_error: 0.1500 - val_loss: 0.0492 - val_mean_absolute_error: 0.1757
# Epoch 16/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0310 - mean_absolute_error: 0.1422 - val_loss: 0.0462 - val_mean_absolute_error: 0.1674
# Epoch 17/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0299 - mean_absolute_error: 0.1378 - val_loss: 0.0468 - val_mean_absolute_error: 0.1648
# Epoch 18/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0257 - mean_absolute_error: 0.1302 - val_loss: 0.0420 - val_mean_absolute_error: 0.1528
# Epoch 19/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0272 - mean_absolute_error: 0.1341 - val_loss: 0.0398 - val_mean_absolute_error: 0.1455
# Epoch 20/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0229 - mean_absolute_error: 0.1219 - val_loss: 0.0391 - val_mean_absolute_error: 0.1424
# Epoch 21/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0255 - mean_absolute_error: 0.1295 - val_loss: 0.0376 - val_mean_absolute_error: 0.1369
# Epoch 22/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0201 - mean_absolute_error: 0.1127 - val_loss: 0.0352 - val_mean_absolute_error: 0.1285
# Epoch 23/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0190 - mean_absolute_error: 0.1102 - val_loss: 0.0344 - val_mean_absolute_error: 0.1250
# Epoch 24/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0185 - mean_absolute_error: 0.1077 - val_loss: 0.0333 - val_mean_absolute_error: 0.1213
# Epoch 25/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0179 - mean_absolute_error: 0.1040 - val_loss: 0.0333 - val_mean_absolute_error: 0.1213
# Epoch 26/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0168 - mean_absolute_error: 0.1026 - val_loss: 0.0325 - val_mean_absolute_error: 0.1188
# Epoch 27/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0171 - mean_absolute_error: 0.1008 - val_loss: 0.0315 - val_mean_absolute_error: 0.1125
# Epoch 28/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0177 - mean_absolute_error: 0.1032 - val_loss: 0.0314 - val_mean_absolute_error: 0.1100
# Epoch 29/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0159 - mean_absolute_error: 0.0950 - val_loss: 0.0306 - val_mean_absolute_error: 0.1088
# Epoch 30/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0186 - mean_absolute_error: 0.1046 - val_loss: 0.0302 - val_mean_absolute_error: 0.1100
# Epoch 31/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0158 - mean_absolute_error: 0.0960 - val_loss: 0.0303 - val_mean_absolute_error: 0.1049
# Epoch 32/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0151 - mean_absolute_error: 0.0930 - val_loss: 0.0297 - val_mean_absolute_error: 0.1071
# Epoch 33/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0163 - mean_absolute_error: 0.0962 - val_loss: 0.0295 - val_mean_absolute_error: 0.1040
# Epoch 34/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0150 - mean_absolute_error: 0.0931 - val_loss: 0.0307 - val_mean_absolute_error: 0.1016
# Epoch 35/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0176 - mean_absolute_error: 0.1000 - val_loss: 0.0315 - val_mean_absolute_error: 0.1022
# Epoch 36/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0176 - mean_absolute_error: 0.1031 - val_loss: 0.0300 - val_mean_absolute_error: 0.0997

# %%
train_predictions = model.predict(X_train).flatten()

plt.figure(figsize=(10, 5))
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])

# Formaterer x-aksen
plt.gcf().autofmt_xdate() # auto roter

# labels og title
plt.xlabel('Date')
plt.ylabel('Euro')
plt.title('Training vs observed')

plt.show()
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.figure(figsize=(10, 5))
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])

# Formaterer x-aksen til å vise datoer og roterer dem
plt.gcf().autofmt_xdate()  # Automatisk rotasjon av datoer fordi det ser pent ut:)


# Adder labels og title
plt.xlabel('Date')
plt.ylabel('Euro')
plt.title('Validation')

plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.figure(figsize=(10, 5))
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])

# Formaterer x-aksen til å vise datoer og roterer dem
plt.gcf().autofmt_xdate()  # Automatisk rotasjon av datoer fordi det ser pent ut:)

# Adder labels og title
plt.xlabel('Date')
plt.ylabel('Euro')
plt.title('Predictions vs observations')

# Vis plot
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step

# %%
plt.figure(figsize=(10, 5))
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# Formaterer x-aksen til å vise datoer og roterer dem
plt.gcf().autofmt_xdate()  # Automatisk rotasjon av datoer

# Adder labels og title
plt.xlabel('Date')
plt.ylabel('Euro')
plt.title('Aegon NV, option prices')

plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, test_predictions)

# Mean Squared Error (MSE)
mse = mean_squared_error(y_test, test_predictions)

# Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# R-squared (R²)
r2 = r2_score(y_test, test_predictions)

# Outputs
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# Mean Absolute Error (MAE): 0.0781
# Mean Squared Error (MSE): 0.0083
# Root Mean Squared Error (RMSE): 0.0911
# R-squared (R²): 0.9023
